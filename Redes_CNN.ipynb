# %% [markdown]
# <a href="https://colab.research.google.com/github/DCDPUAEM/DCDP/blob/main/04%20Deep%20Learning/notebooks/Practica-2-CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Práctica 2</h1>
#
# <h2>Redes CNN</h2>
#
# Continuaremos con el trábado en el dataset Fashion MNIST.
#
# <img align="center" width="50%" src="https://github.com/DCDPUAEM/DCDP/blob/main/04%20Deep%20Learning/img/Fashion-MNIST.jpg?raw=1"/>
#
# [Más información sobre el dataset](https://keras.io/api/datasets/fashion_mnist/)

# %%
from keras.datasets import fashion_mnist
from keras.utils import to_categorical

#-------- Dataset --------

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

print(f"X_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")

#-------- Reescalamiento --------
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

#-------- Codificación vectores de clase --------
print(f"y_train shape (valores de clase):\n{y_train.shape}")
num_classes = 10
y_train = to_categorical(y_train,num_classes)
y_test = to_categorical(y_test,num_classes)
print(f"y_train shape (vectores de clase):\n{y_train.shape}")

#-------- Reshape para incluir el número de canales de la imágen --------
print(f"x_train shape (antes):\n{x_train.shape}")
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], x_test.shape[2], 1))
print(f"x_train shape (después):\n{x_train.shape}")
# Out:
# X_train shape: (60000, 28, 28)
# y_train shape: (60000,)
# X_test shape: (10000, 28, 28)
# y_test shape: (10000,)
# y_train shape (valores de clase):
# (60000,)
# y_train shape (vectores de clase):
# (60000, 10)
# x_train shape (antes):
# (60000, 28, 28)
# x_train shape (después):
# (60000, 28, 28, 1)

# %%
#graficar curvas de entrenamiento

import matplotlib.pyplot as plt

def graficar_curvas(history):
    fig, axs = plt.subplots(1, 2, figsize=(10, 5))
    axs[0].plot(history.history['loss'],label='Training')
    axs[0].plot(history.history['val_loss'],label='Validation')
    axs[0].set_title('Loss')
    axs[0].legend()
    axs[1].plot(history.history['accuracy'],label='Training')
    axs[1].plot(history.history['val_accuracy'],label='Validation')
    axs[1].set_title('Accuracy')
    axs[1].legend()
    fig.show()

# %% [markdown]
# Recordemos el rendimiento de los algoritmos de Machine Learning clásico:
#
# <img align="center" width="40%" src="https://github.com/DCDPUAEM/DCDP/blob/main/04%20Deep%20Learning/img/ML-Fashion-Mnist.png?raw=1"/>

# %% [markdown]
# El modelo básico trabajado en clase

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout

model = Sequential()
model.add(Conv2D(filters=16,kernel_size=3,activation='relu',
                padding="same", strides=1,
                 input_shape=(x_train.shape[1], x_train.shape[2], 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.summary()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 28, 28, 16)        160
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 16)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 3136)              0
#
#  dense_4 (Dense)             (None, 50)                156850
#
#  dense_5 (Dense)             (None, 10)                510
#
# =================================================================
# Total params: 157520 (615.31 KB)
# Trainable params: 157520 (615.31 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=30, batch_size=64, validation_split=0.1, verbose=1)

graficar_curvas(history) # Graficar curvas de entrenamiento
# Out:
# Epoch 1/30
# 844/844 [==============================] - 29s 33ms/step - loss: 0.4805 - accuracy: 0.8349 - val_loss: 0.3316 - val_accuracy: 0.8792
# Epoch 2/30
# 844/844 [==============================] - 22s 26ms/step - loss: 0.3130 - accuracy: 0.8906 - val_loss: 0.2951 - val_accuracy: 0.8933
# Epoch 3/30
# 844/844 [==============================] - 20s 24ms/step - loss: 0.2723 - accuracy: 0.9015 - val_loss: 0.2743 - val_accuracy: 0.9032
# Epoch 4/30
# 844/844 [==============================] - 22s 26ms/step - loss: 0.2459 - accuracy: 0.9114 - val_loss: 0.2806 - val_accuracy: 0.8963
# Epoch 5/30
# 844/844 [==============================] - 18s 21ms/step - loss: 0.2256 - accuracy: 0.9180 - val_loss: 0.2545 - val_accuracy: 0.9080
# Epoch 6/30
# 844/844 [==============================] - 20s 24ms/step - loss: 0.2099 - accuracy: 0.9230 - val_loss: 0.2580 - val_accuracy: 0.9082
# Epoch 7/30
# 844/844 [==============================] - 19s 22ms/step - loss: 0.1930 - accuracy: 0.9299 - val_loss: 0.2474 - val_accuracy: 0.9095
# Epoch 8/30
# 844/844 [==============================] - 18s 21ms/step - loss: 0.1800 - accuracy: 0.9343 - val_loss: 0.2551 - val_accuracy: 0.9133
# Epoch 9/30
# 844/844 [==============================] - 21s 25ms/step - loss: 0.1691 - accuracy: 0.9394 - val_loss: 0.2598 - val_accuracy: 0.9072
# Epoch 10/30
# 844/844 [==============================] - 18s 22ms/step - loss: 0.1552 - accuracy: 0.9435 - val_loss: 0.2737 - val_accuracy: 0.9062
# Epoch 11/30
# 844/844 [==============================] - 21s 25ms/step - loss: 0.1441 - accuracy: 0.9475 - val_loss: 0.2492 - val_accuracy: 0.9175
# Epoch 12/30
# 844/844 [==============================] - 18s 22ms/step - loss: 0.1340 - accuracy: 0.9512 - val_loss: 0.2565 - val_accuracy: 0.9143
# Epoch 13/30
# 844/844 [==============================] - 19s 22ms/step - loss: 0.1245 - accuracy: 0.9551 - val_loss: 0.2663 - val_accuracy: 0.9138
# Epoch 14/30
# 844/844 [==============================] - 20s 23ms/step - loss: 0.1142 - accuracy: 0.9587 - val_loss: 0.2652 - val_accuracy: 0.9160
# Epoch 15/30
# 844/844 [==============================] - 19s 22ms/step - loss: 0.1065 - accuracy: 0.9619 - val_loss: 0.2827 - val_accuracy: 0.9123
# Epoch 16/30
# 844/844 [==============================] - 20s 24ms/step - loss: 0.0985 - accuracy: 0.9647 - val_loss: 0.2747 - val_accuracy: 0.9165
# Epoch 17/30
# 844/844 [==============================] - 20s 23ms/step - loss: 0.0924 - accuracy: 0.9668 - val_loss: 0.3112 - val_accuracy: 0.9107
# Epoch 18/30
# 844/844 [==============================] - 21s 25ms/step - loss: 0.0859 - accuracy: 0.9692 - val_loss: 0.3224 - val_accuracy: 0.9068
# Epoch 19/30
# 844/844 [==============================] - 19s 22ms/step - loss: 0.0787 - accuracy: 0.9727 - val_loss: 0.3051 - val_accuracy: 0.9138
# Epoch 20/30
# 844/844 [==============================] - 20s 23ms/step - loss: 0.0730 - accuracy: 0.9741 - val_loss: 0.3241 - val_accuracy: 0.9123
# Epoch 21/30
# 844/844 [==============================] - 19s 23ms/step - loss: 0.0684 - accuracy: 0.9761 - val_loss: 0.3340 - val_accuracy: 0.9118
# Epoch 22/30
# 844/844 [==============================] - 19s 23ms/step - loss: 0.0621 - accuracy: 0.9787 - val_loss: 0.3451 - val_accuracy: 0.9133
# Epoch 23/30
# 844/844 [==============================] - 19s 23ms/step - loss: 0.0578 - accuracy: 0.9799 - val_loss: 0.3520 - val_accuracy: 0.9120
# Epoch 24/30
# 844/844 [==============================] - 21s 25ms/step - loss: 0.0534 - accuracy: 0.9816 - val_loss: 0.3598 - val_accuracy: 0.9133
# Epoch 25/30
# 844/844 [==============================] - 19s 23ms/step - loss: 0.0503 - accuracy: 0.9827 - val_loss: 0.3853 - val_accuracy: 0.9080
# Epoch 26/30
# 844/844 [==============================] - 19s 23ms/step - loss: 0.0476 - accuracy: 0.9831 - val_loss: 0.3914 - val_accuracy: 0.9112
# Epoch 27/30
# 844/844 [==============================] - 19s 23ms/step - loss: 0.0426 - accuracy: 0.9856 - val_loss: 0.4147 - val_accuracy: 0.9102
# Epoch 28/30
# 844/844 [==============================] - 19s 22ms/step - loss: 0.0420 - accuracy: 0.9859 - val_loss: 0.4292 - val_accuracy: 0.9112
# Epoch 29/30
# 844/844 [==============================] - 20s 23ms/step - loss: 0.0362 - accuracy: 0.9877 - val_loss: 0.4384 - val_accuracy: 0.9110
# Epoch 30/30
# 844/844 [==============================] - 18s 22ms/step - loss: 0.0350 - accuracy: 0.9875 - val_loss: 0.4769 - val_accuracy: 0.9083

# %% [markdown]
# ⭕ Práctica
#
# Usando el mismo dataset, implementa las siguientes redes CNN usando como punto de partida la red que hemos implementado, ya sea la versión como función o la *normal* (si te sientes insegura/o respecto a la implementación, no uses el enfoque de función):
#
# * Una red CNN con dos capas convolucionales, en lugar de uno. La segunda capa tendrá las siguientes especificaciones:
#  * Una capa convolucional 2D de 8 filtros, el resto de hiperparámetros serán los mismos.
#  * Una capa de MaxPooling.
# * La red CNN anterior, con las mismas dos capas convolucionales. Cambia la función de activación por `tanh`. ¿Cómo cambian los resultados?
# * La red CNN anterior, con las mismas dos capas convolucionales. Cambia el hiperparámetro `padding='valid'`. ¿Qué observas?
# * La red CNN anterior, con las mismas dos capas convolucionales. En la parte MLP de la red, agrega 3 capas densas. Usa el número de neuronas en estas capas de tu elección, así como la función de activación en ellas. Experimenta un poco.
# * Una red CNN con una capa convolucional con 32 filtros, la parte MLP tendrá un capa oculta de 100 neuronas con activación `relu`. Para el optimizador una un [`SGD`](https://keras.io/api/optimizers/sgd/) con tasa de aprendizaje $0.01$.

# %%
#1 Una red CNN con dos capas convolucionales, en lugar de uno


model = Sequential()
model.add(Conv2D(filters=16, kernel_size=3, activation='relu',
                 padding='same', strides=1,
                 input_shape=(x_train.shape[1], x_train.shape[2], 1)))

# Segunda capa
model.add(Conv2D(filters=8, kernel_size=3, activation='relu',
                 padding='same', strides=1))

# Capa MaxPooling
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(50, activation='relu'))

model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_split=0.2, verbose=1)

graficar_curvas(history)
# Out:
# Epoch 1/10
# 750/750 [==============================] - 54s 71ms/step - loss: 0.5264 - accuracy: 0.8121 - val_loss: 0.4357 - val_accuracy: 0.8459
# Epoch 2/10
# 750/750 [==============================] - 42s 56ms/step - loss: 0.3408 - accuracy: 0.8784 - val_loss: 0.3102 - val_accuracy: 0.8888
# Epoch 3/10
# 750/750 [==============================] - 41s 54ms/step - loss: 0.2942 - accuracy: 0.8949 - val_loss: 0.2855 - val_accuracy: 0.8977
# Epoch 4/10
# 750/750 [==============================] - 41s 54ms/step - loss: 0.2608 - accuracy: 0.9048 - val_loss: 0.2708 - val_accuracy: 0.9013
# Epoch 5/10
# 750/750 [==============================] - 42s 56ms/step - loss: 0.2363 - accuracy: 0.9142 - val_loss: 0.2637 - val_accuracy: 0.9033
# Epoch 6/10
# 750/750 [==============================] - 42s 56ms/step - loss: 0.2124 - accuracy: 0.9230 - val_loss: 0.2553 - val_accuracy: 0.9068
# Epoch 7/10
# 750/750 [==============================] - 40s 54ms/step - loss: 0.1976 - accuracy: 0.9273 - val_loss: 0.2384 - val_accuracy: 0.9143
# Epoch 8/10
# 750/750 [==============================] - 48s 64ms/step - loss: 0.1786 - accuracy: 0.9340 - val_loss: 0.2443 - val_accuracy: 0.9098
# Epoch 9/10
# 750/750 [==============================] - 44s 59ms/step - loss: 0.1656 - accuracy: 0.9379 - val_loss: 0.2376 - val_accuracy: 0.9153
# Epoch 10/10
# 750/750 [==============================] - 42s 56ms/step - loss: 0.1518 - accuracy: 0.9444 - val_loss: 0.2477 - val_accuracy: 0.9141

# %%
#2 La red CNN anterior, con las mismas dos capas convolucionales. Cambia la función de activación por tanh.
#¿Cómo cambian los resultados?
#R= En la activación RELU tiene una mejor precisión y validación, los resultados con tanh tiene mayor pérdida


model = Sequential()
model.add(Conv2D(filters=16, kernel_size=3, activation='tanh',
                 padding='same', strides=1,
                 input_shape=(x_train.shape[1], x_train.shape[2], 1)))


model.add(Conv2D(filters=8, kernel_size=3, activation='tanh',
                 padding='same', strides=1))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(50, activation='tanh'))

model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_split=0.2, verbose=1)

graficar_curvas(history)
# Out:
# Epoch 1/10
# 750/750 [==============================] - 43s 56ms/step - loss: 0.4813 - accuracy: 0.8265 - val_loss: 0.3590 - val_accuracy: 0.8716
# Epoch 2/10
# 750/750 [==============================] - 40s 54ms/step - loss: 0.3213 - accuracy: 0.8848 - val_loss: 0.3074 - val_accuracy: 0.8879
# Epoch 3/10
# 750/750 [==============================] - 42s 55ms/step - loss: 0.2753 - accuracy: 0.9002 - val_loss: 0.2946 - val_accuracy: 0.8903
# Epoch 4/10
# 750/750 [==============================] - 42s 56ms/step - loss: 0.2414 - accuracy: 0.9121 - val_loss: 0.2669 - val_accuracy: 0.9025
# Epoch 5/10
# 750/750 [==============================] - 41s 55ms/step - loss: 0.2161 - accuracy: 0.9223 - val_loss: 0.2556 - val_accuracy: 0.9040
# Epoch 6/10
# 750/750 [==============================] - 41s 55ms/step - loss: 0.1939 - accuracy: 0.9300 - val_loss: 0.2554 - val_accuracy: 0.9062
# Epoch 7/10
# 750/750 [==============================] - 43s 57ms/step - loss: 0.1748 - accuracy: 0.9367 - val_loss: 0.2577 - val_accuracy: 0.9078
# Epoch 8/10
# 750/750 [==============================] - 44s 59ms/step - loss: 0.1598 - accuracy: 0.9422 - val_loss: 0.2661 - val_accuracy: 0.9072
# Epoch 9/10
# 750/750 [==============================] - 41s 55ms/step - loss: 0.1460 - accuracy: 0.9481 - val_loss: 0.2674 - val_accuracy: 0.9057
# Epoch 10/10
# 750/750 [==============================] - 45s 60ms/step - loss: 0.1315 - accuracy: 0.9531 - val_loss: 0.2749 - val_accuracy: 0.9032

# %%
#3 La red CNN anterior, con las mismas dos capas convolucionales. Cambia el hiperparámetro padding='valid'. ¿Qué observas?
#R= La precisión y la pérdida es un poco peor comparada con padding same


model = Sequential()
model.add(Conv2D(filters=16, kernel_size=3, activation='tanh',
                 padding='valid', strides=1,
                 input_shape=(x_train.shape[1], x_train.shape[2], 1)))

model.add(MaxPooling2D((2, 2)))


model.add(Conv2D(filters=8, kernel_size=3, activation='tanh',
                 padding='valid'))

model.add(MaxPooling2D((2, 2)))

model.add(Flatten())

model.add(Dense(50, activation='tanh'))

model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))

graficar_curvas(history)
# Out:
# Epoch 1/10
# 938/938 [==============================] - 28s 28ms/step - loss: 0.6070 - accuracy: 0.7834 - val_loss: 0.4556 - val_accuracy: 0.8354
# Epoch 2/10
# 938/938 [==============================] - 25s 27ms/step - loss: 0.3959 - accuracy: 0.8554 - val_loss: 0.4031 - val_accuracy: 0.8532
# Epoch 3/10
# 938/938 [==============================] - 24s 25ms/step - loss: 0.3528 - accuracy: 0.8709 - val_loss: 0.3578 - val_accuracy: 0.8682
# Epoch 4/10
# 938/938 [==============================] - 22s 24ms/step - loss: 0.3299 - accuracy: 0.8792 - val_loss: 0.3389 - val_accuracy: 0.8769
# Epoch 5/10
# 938/938 [==============================] - 24s 25ms/step - loss: 0.3119 - accuracy: 0.8859 - val_loss: 0.3376 - val_accuracy: 0.8776
# Epoch 6/10
# 938/938 [==============================] - 25s 27ms/step - loss: 0.2979 - accuracy: 0.8903 - val_loss: 0.3221 - val_accuracy: 0.8830
# Epoch 7/10
# 938/938 [==============================] - 25s 26ms/step - loss: 0.2868 - accuracy: 0.8946 - val_loss: 0.3109 - val_accuracy: 0.8891
# Epoch 8/10
# 938/938 [==============================] - 25s 27ms/step - loss: 0.2777 - accuracy: 0.8982 - val_loss: 0.3055 - val_accuracy: 0.8907
# Epoch 9/10
# 938/938 [==============================] - 23s 24ms/step - loss: 0.2690 - accuracy: 0.9015 - val_loss: 0.3045 - val_accuracy: 0.8890
# Epoch 10/10
# 938/938 [==============================] - 28s 30ms/step - loss: 0.2632 - accuracy: 0.9040 - val_loss: 0.2999 - val_accuracy: 0.8919

# %%
#4 La red CNN anterior, con las mismas dos capas convolucionales. En la parte MLP de la red, agrega 3 capas densas.
#Usa el número de neuronas en estas capas de tu elección, así como la función de activación en ellas.

model = Sequential()

model.add(Conv2D(filters=16, kernel_size=3, activation='relu',
                 padding='valid', strides=1,
                 input_shape=(x_train.shape[1], x_train.shape[2], 1)))

model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(filters=8, kernel_size=3, activation='relu',
                 padding='valid'))

model.add(MaxPooling2D((2, 2)))

model.add(Flatten())

# Capas adicionales
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))

model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))

graficar_curvas(history)
# Out:
# Epoch 1/10
# 938/938 [==============================] - 25s 25ms/step - loss: 0.6584 - accuracy: 0.7566 - val_loss: 0.4847 - val_accuracy: 0.8259
# Epoch 2/10
# 938/938 [==============================] - 24s 26ms/step - loss: 0.4328 - accuracy: 0.8419 - val_loss: 0.4226 - val_accuracy: 0.8457
# Epoch 3/10
# 938/938 [==============================] - 22s 24ms/step - loss: 0.3758 - accuracy: 0.8638 - val_loss: 0.3782 - val_accuracy: 0.8620
# Epoch 4/10
# 938/938 [==============================] - 25s 27ms/step - loss: 0.3457 - accuracy: 0.8734 - val_loss: 0.3804 - val_accuracy: 0.8632
# Epoch 5/10
# 938/938 [==============================] - 23s 24ms/step - loss: 0.3242 - accuracy: 0.8799 - val_loss: 0.3447 - val_accuracy: 0.8724
# Epoch 6/10
# 938/938 [==============================] - 22s 23ms/step - loss: 0.3064 - accuracy: 0.8877 - val_loss: 0.3438 - val_accuracy: 0.8741
# Epoch 7/10
# 938/938 [==============================] - 23s 24ms/step - loss: 0.2947 - accuracy: 0.8913 - val_loss: 0.3287 - val_accuracy: 0.8804
# Epoch 8/10
# 938/938 [==============================] - 25s 27ms/step - loss: 0.2834 - accuracy: 0.8944 - val_loss: 0.3252 - val_accuracy: 0.8792
# Epoch 9/10
# 938/938 [==============================] - 23s 25ms/step - loss: 0.2718 - accuracy: 0.8986 - val_loss: 0.3199 - val_accuracy: 0.8836
# Epoch 10/10
# 938/938 [==============================] - 24s 25ms/step - loss: 0.2638 - accuracy: 0.9014 - val_loss: 0.3246 - val_accuracy: 0.8810

# %%
#5 Una red CNN con una capa convolucional con 32 filtros, la parte MLP tendrá un capa oculta de 100 neuronas con activación relu.
#Para el optimizador una un SGD con tasa de aprendizaje  0.01 .

from keras.optimizers import SGD

model = Sequential()

model.add(Conv2D(filters=32, kernel_size=3, activation='relu',
                 padding='same', strides=1,
                 input_shape=(x_train.shape[1], x_train.shape[2], 1)))

model.add(MaxPooling2D((2, 2)))

model.add(Flatten())

model.add(Dense(100, activation='relu'))

model.add(Dense(10, activation='softmax'))

#Optimizador
optimizer = SGD(learning_rate=0.01)

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))

graficar_curvas(history)
# Out:
# Epoch 1/10
# 938/938 [==============================] - 35s 37ms/step - loss: 0.8254 - accuracy: 0.7230 - val_loss: 0.5642 - val_accuracy: 0.7906
# Epoch 2/10
# 938/938 [==============================] - 34s 36ms/step - loss: 0.5133 - accuracy: 0.8160 - val_loss: 0.7400 - val_accuracy: 0.7237
# Epoch 3/10
# 938/938 [==============================] - 34s 37ms/step - loss: 0.4673 - accuracy: 0.8340 - val_loss: 0.4660 - val_accuracy: 0.8357
# Epoch 4/10
# 938/938 [==============================] - 32s 34ms/step - loss: 0.4321 - accuracy: 0.8483 - val_loss: 0.4918 - val_accuracy: 0.8184
# Epoch 5/10
# 938/938 [==============================] - 35s 37ms/step - loss: 0.4087 - accuracy: 0.8559 - val_loss: 0.4563 - val_accuracy: 0.8360
# Epoch 6/10
# 938/938 [==============================] - 33s 35ms/step - loss: 0.3894 - accuracy: 0.8637 - val_loss: 0.4625 - val_accuracy: 0.8328
# Epoch 7/10
# 938/938 [==============================] - 33s 35ms/step - loss: 0.3731 - accuracy: 0.8680 - val_loss: 0.4053 - val_accuracy: 0.8564
# Epoch 8/10
# 938/938 [==============================] - 33s 35ms/step - loss: 0.3584 - accuracy: 0.8736 - val_loss: 0.4328 - val_accuracy: 0.8496
# Epoch 9/10
# 938/938 [==============================] - 34s 36ms/step - loss: 0.3468 - accuracy: 0.8774 - val_loss: 0.3735 - val_accuracy: 0.8663
# Epoch 10/10
# 938/938 [==============================] - 34s 36ms/step - loss: 0.3369 - accuracy: 0.8813 - val_loss: 0.3574 - val_accuracy: 0.8732

# %% [markdown]
# * Implementa una red MLP para este mismo problema. Prueba al menos 3 arquitecturas diferentes, ¿cuál fue la mejor opción? ¿cómo se compara con una CNN?
#  * No olvides el conjunto de validación.
#  * Usa el callback de `EarlyStopping`.
#  * Cuida no re-entrenar modelos.
#
# Para este último punto, usa el siguiente código para preparar el dataset:

# %%
from keras.datasets import fashion_mnist

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

print("Shapes al cargar el dataset:")
print(f"X train shape: {X_train.shape}")
print(f"y train shape: {y_train.shape}")
print(f"X test shape: {X_test.shape}")
print(f"y test shape: {y_test.shape}")

num_classes = 10
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

X_train = X_train.reshape(-1, 784)
X_test = X_test.reshape(-1, 784)

print("\nShapes al preprocesar el dataset:")
print(f"X train shape: {X_train.shape}")
print(f"y train shape: {y_train.shape}")
print(f"X test shape: {X_test.shape}")
print(f"y test shape: {y_test.shape}")
# Out:
# Shapes al cargar el dataset:
# X train shape: (60000, 28, 28)
# y train shape: (60000,)
# X test shape: (10000, 28, 28)
# y test shape: (10000,)
#
# Shapes al preprocesar el dataset:
# X train shape: (60000, 784)
# y train shape: (60000, 10)
# X test shape: (10000, 784)
# y test shape: (10000, 10)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.optimizers import SGD

model = Sequential()
model.add(Dense(50, activation='relu', input_shape=(784,)))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer=SGD(learning_rate=0.01), loss='categorical_crossentropy', metrics=['accuracy'])

# EarlyStopping
stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=30, batch_size=64, validation_split=0.2, callbacks=[stop])

loss, accuracy = model.evaluate(X_test, y_test)
print(f"Prueba 1 - Loss: {loss}, Precisión: {accuracy}")

graficar_curvas(history)
# Out:
# Epoch 1/30
# 750/750 [==============================] - 4s 4ms/step - loss: 0.9896 - accuracy: 0.6896 - val_loss: 0.6879 - val_accuracy: 0.7659
# Epoch 2/30
# 750/750 [==============================] - 3s 3ms/step - loss: 0.6349 - accuracy: 0.7889 - val_loss: 0.5877 - val_accuracy: 0.8008
# Epoch 3/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5625 - accuracy: 0.8114 - val_loss: 0.5374 - val_accuracy: 0.8178
# Epoch 4/30
# 750/750 [==============================] - 3s 3ms/step - loss: 0.5237 - accuracy: 0.8246 - val_loss: 0.5165 - val_accuracy: 0.8229
# Epoch 5/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4984 - accuracy: 0.8312 - val_loss: 0.4978 - val_accuracy: 0.8257
# Epoch 6/30
# 750/750 [==============================] - 5s 7ms/step - loss: 0.4799 - accuracy: 0.8368 - val_loss: 0.4946 - val_accuracy: 0.8251
# Epoch 7/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4655 - accuracy: 0.8401 - val_loss: 0.4711 - val_accuracy: 0.8348
# Epoch 8/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4538 - accuracy: 0.8455 - val_loss: 0.4586 - val_accuracy: 0.8419
# Epoch 9/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4450 - accuracy: 0.8479 - val_loss: 0.4461 - val_accuracy: 0.8456
# Epoch 10/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4359 - accuracy: 0.8491 - val_loss: 0.4501 - val_accuracy: 0.8411
# Epoch 11/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4286 - accuracy: 0.8529 - val_loss: 0.4425 - val_accuracy: 0.8424
# Epoch 12/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4219 - accuracy: 0.8545 - val_loss: 0.4520 - val_accuracy: 0.8403
# Epoch 13/30
# 750/750 [==============================] - 3s 3ms/step - loss: 0.4156 - accuracy: 0.8575 - val_loss: 0.4253 - val_accuracy: 0.8517
# Epoch 14/30
# 750/750 [==============================] - 3s 3ms/step - loss: 0.4098 - accuracy: 0.8587 - val_loss: 0.4250 - val_accuracy: 0.8503
# Epoch 15/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4053 - accuracy: 0.8598 - val_loss: 0.4179 - val_accuracy: 0.8562
# Epoch 16/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4003 - accuracy: 0.8613 - val_loss: 0.4120 - val_accuracy: 0.8564
# Epoch 17/30
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3959 - accuracy: 0.8632 - val_loss: 0.4084 - val_accuracy: 0.8580
# Epoch 18/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3917 - accuracy: 0.8653 - val_loss: 0.4085 - val_accuracy: 0.8575
# Epoch 19/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3881 - accuracy: 0.8655 - val_loss: 0.4036 - val_accuracy: 0.8620
# Epoch 20/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3842 - accuracy: 0.8678 - val_loss: 0.4038 - val_accuracy: 0.8581
# Epoch 21/30
# 750/750 [==============================] - 3s 3ms/step - loss: 0.3809 - accuracy: 0.8676 - val_loss: 0.4006 - val_accuracy: 0.8603
# Epoch 22/30
# 750/750 [==============================] - 3s 3ms/step - loss: 0.3776 - accuracy: 0.8694 - val_loss: 0.3968 - val_accuracy: 0.8630
# Epoch 23/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3747 - accuracy: 0.8703 - val_loss: 0.3938 - val_accuracy: 0.8629
# Epoch 24/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3716 - accuracy: 0.8708 - val_loss: 0.3977 - val_accuracy: 0.8626
# Epoch 25/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3679 - accuracy: 0.8729 - val_loss: 0.3899 - val_accuracy: 0.8635
# Epoch 26/30
# 750/750 [==============================] - 3s 3ms/step - loss: 0.3654 - accuracy: 0.8735 - val_loss: 0.3869 - val_accuracy: 0.8657
# Epoch 27/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3625 - accuracy: 0.8749 - val_loss: 0.3926 - val_accuracy: 0.8624
# Epoch 28/30
# 750/750 [==============================] - 3s 3ms/step - loss: 0.3604 - accuracy: 0.8751 - val_loss: 0.3915 - val_accuracy: 0.8624
# Epoch 29/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3582 - accuracy: 0.8762 - val_loss: 0.3831 - val_accuracy: 0.8690
# Epoch 30/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3558 - accuracy: 0.8762 - val_loss: 0.3846 - val_accuracy: 0.8666
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4120 - accuracy: 0.8547
# Prueba 1 - Loss: 0.4120478928089142, Precisión: 0.8547000288963318

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(784,)))
model.add(Dense(50, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer=SGD(learning_rate=0.01), loss='categorical_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=30, batch_size=64, validation_split=0.2, callbacks=[early_stopping])

loss, accuracy = model.evaluate(X_test, y_test)
print(f"Prueba 2 - Loss: {loss}, Precisión: {accuracy}")

graficar_curvas(history)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                50240
#
#  dense_9 (Dense)             (None, 50)                3250
#
#  dense_10 (Dense)            (None, 10)                510
#
# =================================================================
# Total params: 54000 (210.94 KB)
# Trainable params: 54000 (210.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 750/750 [==============================] - 3s 4ms/step - loss: 1.0546 - accuracy: 0.6593 - val_loss: 0.6840 - val_accuracy: 0.7600
# Epoch 2/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.6130 - accuracy: 0.7920 - val_loss: 0.5622 - val_accuracy: 0.8055
# Epoch 3/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.5359 - accuracy: 0.8165 - val_loss: 0.5148 - val_accuracy: 0.8216
# Epoch 4/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4979 - accuracy: 0.8275 - val_loss: 0.5053 - val_accuracy: 0.8225
# Epoch 5/30
# 750/750 [==============================] - 5s 6ms/step - loss: 0.4747 - accuracy: 0.8351 - val_loss: 0.4796 - val_accuracy: 0.8308
# Epoch 6/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4561 - accuracy: 0.8411 - val_loss: 0.4609 - val_accuracy: 0.8396
# Epoch 7/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4422 - accuracy: 0.8462 - val_loss: 0.4533 - val_accuracy: 0.8398
# Epoch 8/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4319 - accuracy: 0.8497 - val_loss: 0.4371 - val_accuracy: 0.8460
# Epoch 9/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4208 - accuracy: 0.8528 - val_loss: 0.4440 - val_accuracy: 0.8397
# Epoch 10/30
# 750/750 [==============================] - 3s 3ms/step - loss: 0.4124 - accuracy: 0.8552 - val_loss: 0.4251 - val_accuracy: 0.8518
# Epoch 11/30
# 750/750 [==============================] - 3s 5ms/step - loss: 0.4035 - accuracy: 0.8588 - val_loss: 0.4187 - val_accuracy: 0.8556
# Epoch 12/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3976 - accuracy: 0.8604 - val_loss: 0.4106 - val_accuracy: 0.8566
# Epoch 13/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3904 - accuracy: 0.8632 - val_loss: 0.4127 - val_accuracy: 0.8537
# Epoch 14/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3849 - accuracy: 0.8656 - val_loss: 0.3967 - val_accuracy: 0.8608
# Epoch 15/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3783 - accuracy: 0.8670 - val_loss: 0.4022 - val_accuracy: 0.8576
# Epoch 16/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3730 - accuracy: 0.8691 - val_loss: 0.3944 - val_accuracy: 0.8603
# Epoch 17/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3687 - accuracy: 0.8709 - val_loss: 0.3937 - val_accuracy: 0.8611
# Epoch 18/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3641 - accuracy: 0.8716 - val_loss: 0.3877 - val_accuracy: 0.8627
# Epoch 19/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3590 - accuracy: 0.8733 - val_loss: 0.3786 - val_accuracy: 0.8649
# Epoch 20/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3553 - accuracy: 0.8746 - val_loss: 0.3777 - val_accuracy: 0.8650
# Epoch 21/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3509 - accuracy: 0.8760 - val_loss: 0.4049 - val_accuracy: 0.8525
# Epoch 22/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3470 - accuracy: 0.8762 - val_loss: 0.3749 - val_accuracy: 0.8701
# Epoch 23/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3434 - accuracy: 0.8788 - val_loss: 0.3789 - val_accuracy: 0.8665
# Epoch 24/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3400 - accuracy: 0.8793 - val_loss: 0.3719 - val_accuracy: 0.8678
# Epoch 25/30
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3372 - accuracy: 0.8808 - val_loss: 0.3666 - val_accuracy: 0.8674
# Epoch 26/30
# 750/750 [==============================] - 3s 5ms/step - loss: 0.3328 - accuracy: 0.8804 - val_loss: 0.3745 - val_accuracy: 0.8670
# Epoch 27/30
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3307 - accuracy: 0.8825 - val_loss: 0.3600 - val_accuracy: 0.8732
# Epoch 28/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3268 - accuracy: 0.8842 - val_loss: 0.3659 - val_accuracy: 0.8702
# Epoch 29/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3238 - accuracy: 0.8849 - val_loss: 0.3691 - val_accuracy: 0.8707
# Epoch 30/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3204 - accuracy: 0.8858 - val_loss: 0.3589 - val_accuracy: 0.8721
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3870 - accuracy: 0.8647
# Prueba 2 - Loss: 0.3869822323322296, Precisión: 0.8647000193595886

# %%
model = Sequential()
model.add(Dense(100, activation='relu', input_shape=(784,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer=SGD(learning_rate=0.01), loss='categorical_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=30, batch_size=64, validation_split=0.2, callbacks=[early_stopping])

loss, accuracy = model.evaluate(X_test, y_test)
print(f"Prueba 3 - Loss: {loss}, Precisión: {accuracy}")

graficar_curvas(history)
# Out:
# Epoch 1/30
# 750/750 [==============================] - 4s 4ms/step - loss: 1.1010 - accuracy: 0.6381 - val_loss: 0.6712 - val_accuracy: 0.7589
# Epoch 2/30
# 750/750 [==============================] - 3s 3ms/step - loss: 0.6045 - accuracy: 0.7913 - val_loss: 0.5672 - val_accuracy: 0.8001
# Epoch 3/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.5270 - accuracy: 0.8166 - val_loss: 0.5312 - val_accuracy: 0.8095
# Epoch 4/30
# 750/750 [==============================] - 4s 5ms/step - loss: 0.4917 - accuracy: 0.8289 - val_loss: 0.4768 - val_accuracy: 0.8328
# Epoch 5/30
# 750/750 [==============================] - 3s 3ms/step - loss: 0.4650 - accuracy: 0.8363 - val_loss: 0.4648 - val_accuracy: 0.8354
# Epoch 6/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4436 - accuracy: 0.8450 - val_loss: 0.4491 - val_accuracy: 0.8410
# Epoch 7/30
# 750/750 [==============================] - 3s 3ms/step - loss: 0.4282 - accuracy: 0.8493 - val_loss: 0.4274 - val_accuracy: 0.8491
# Epoch 8/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4136 - accuracy: 0.8534 - val_loss: 0.4156 - val_accuracy: 0.8534
# Epoch 9/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4017 - accuracy: 0.8596 - val_loss: 0.4170 - val_accuracy: 0.8525
# Epoch 10/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3920 - accuracy: 0.8620 - val_loss: 0.3987 - val_accuracy: 0.8616
# Epoch 11/30
# 750/750 [==============================] - 3s 5ms/step - loss: 0.3812 - accuracy: 0.8665 - val_loss: 0.3994 - val_accuracy: 0.8598
# Epoch 12/30
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3739 - accuracy: 0.8676 - val_loss: 0.3846 - val_accuracy: 0.8642
# Epoch 13/30
# 750/750 [==============================] - 3s 5ms/step - loss: 0.3659 - accuracy: 0.8720 - val_loss: 0.3945 - val_accuracy: 0.8608
# Epoch 14/30
# 750/750 [==============================] - 3s 3ms/step - loss: 0.3578 - accuracy: 0.8733 - val_loss: 0.3752 - val_accuracy: 0.8686
# Epoch 15/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3524 - accuracy: 0.8745 - val_loss: 0.3723 - val_accuracy: 0.8700
# Epoch 16/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3450 - accuracy: 0.8766 - val_loss: 0.3893 - val_accuracy: 0.8613
# Epoch 17/30
# 750/750 [==============================] - 3s 5ms/step - loss: 0.3393 - accuracy: 0.8785 - val_loss: 0.3776 - val_accuracy: 0.8678
# Epoch 18/30
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3343 - accuracy: 0.8798 - val_loss: 0.3905 - val_accuracy: 0.8631
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3980 - accuracy: 0.8580
# Prueba 3 - Loss: 0.3980250656604767, Precisión: 0.8579999804496765

# %% [markdown]
# Dudas: mauricio.toledo@unison.mx

# %% [markdown]
# Respecto a las dimensiones de salida de una capa convolucional: [wikipedia](https://en.wikipedia.org/wiki/Convolutional_neural_network#Convolutional_layer), [stackoverflow](https://stackoverflow.com/questions/53580088/calculate-the-output-size-in-convolution-layer).
